# %%
# Esta es una modificacion del script original para google colab, para que funcione en github codespaces
# Hecho por @LUCAST o @Lucast1574 o @Lucast_1574 en github y otras redes sociales
# Versiones disponibles testeadas:
# - 1.20.4
# - 1.20.3
# - 1.20.2
# - 1.20.1
# - 1.20
# - 1.19.4
# - 1.19.3
# - 1.19.2
# - 1.19.1
# - 1.19
# - 1.18.2
# - 1.18.1
# - 1.18
# - 1.17.1
# - 1.17
# - 1.16.5
# - 1.16.4
# - 1.16.3
# - 1.15.2
# - 1.14.4
# - 1.13.2
# - 1.12.2
# - 1.11.2
# - 1.10.2
# - 1.9.4
# - 1.8.8


version = '1.20.1' # Version de Minecraft a usar

#Chose server type. Currently available versions:
# - paper (Lo más vanilla. Es lo mismo que SPIGOT, bukkit, etc)
# - forge (Para usar MODS. Es básicamente FORGE) [Aviso, la instalación tarda APROX 10-15 min, al ejecutar el primer paso, esperar a que ponga COMPLETADO]
# - fabric (Para jugar Fabric. Es una alternativa a Forge)
# - vanilla (Minecraft Vanilla sin mods ni plugins)
# - snapshot (En "version" tendrás que poner el nombre de la SNAPSHOT, EJ: 23w42a)
# - mohist (Versión de Minecraft que combina Forge y Bukkit)

server_type = 'mohist'

#Importa librerias necesarias para el funcionamiento del script

import os
import requests
import json


server_directory = "Minecraft-server"

# Crea el directorio del servidor en codespace

os.makedirs(server_directory, exist_ok=True)
os.chdir(server_directory)

# Inicio interno... Descarga el servidor

if server_type == 'paper':
    a = requests.get("https://papermc.io/api/v2/projects/paper/versions/" + version)

    b = requests.get("https://papermc.io/api/v2/projects/paper/versions/" + version + "/builds/" + str(a.json()["builds"][-1]))

    print("https://papermc.io/api/v2/projects/paper/versions/" + version + "/builds/" + str(a.json()["builds"][-1]) + "/downloads/" + b.json()["downloads"]["application"]["name"])
    serverURL = "https://papermc.io/api/v2/projects/paper/versions/" + version + "/builds/" + str(a.json()["builds"][-1]) + "/downloads/" + b.json()["downloads"]["application"]["name"]

if server_type == 'forge':
    serverURL = "https://serverjars.com/api/fetchJar/modded/forge/" + version

if server_type == 'vanilla':
    serverURL = "https://serverjars.com/api/fetchJar/vanilla/vanilla/" + version

if server_type == 'snapshot':
    serverURL = "https://serverjars.com/api/fetchJar/vanilla/snapshot/" + version
if server_type == 'fabric':
    serverURL = 'https://maven.fabricmc.net/net/fabricmc/fabric-installer/0.11.2/fabric-installer-0.11.2.jar'

if server_type == 'mohist':
    serverURL = "https://serverjars.com/api/fetchJar/modded/mohist/" + version

jar_name = {'paper': 'server.jar', 'fabric': 'fabric-installer.jar', 'forge': 'forge.jar', 'vanilla': 'vanilla.jar', 'snapshot': "snapshot.jar", 'mohist': "mohist.jar"}

print('Descargando el tipo de servidor: ')

if serverURL:
    print('Descargando a GitHub Codespaces...')
    r = requests.get(serverURL)

    if r.status_code == 200:
        with open(jar_name[server_type], 'wb') as f:
            f.write(r.content)
    else:
        print('Error '+ str(r.status_code) + '! La versión que has elegido probablemente no funciona.')


# Correr en un camino especifico

if server_type == 'fabric':
    # !java -jar fabric-installer.jar server -mcversion $version -downloadMinecraft

if server_type == 'forge':
    # %cd "/workspaces/codespaces-jupyter/Minecraft-server"
    # !java -jar forge.jar --installServer

# Guarda el archivo de configuración localmente
colabconfig = {"server_type": server_type, "server_version": version}
with open("colabconfig.json", 'w') as config_file:
    json.dump(colabconfig, config_file)

# Imprime un mensaje de finalización
print('Completado!')
# Cambie el eula a true para aceptar los términos de Minecraft
# !echo "eula=true" >> eula.txt
# Out:
# Descargando el tipo de servidor:
# Descargando a GitHub Codespaces...
# Completado!

# %%
#importa librerias necesarias para ejecucion

import requests

import time

import os

import re

import json

import glob

import threading



#Actualizacion de lista de paquetes

# !sudo apt update &>/dev/null && echo "el apt cache fue actualizado correctamente" || echo "la actualizacion del apt cache fallo, es posible que recibas paquetes obsoletos"

#Asignar archivos al directorio


os.makedirs("/workspaces/codespaces-jupyter/Minecraft-server", exist_ok=True)

os.chdir("/workspaces/codespaces-jupyter/Minecraft-server")

# !ls #lista los archivos del directorio para verificarlos



#Importacion del archivo de configuracion


config_path = "/workspaces/codespaces-jupyter/Minecraft-server/colabconfig.json"

if os.path.isfile(config_path):

    with open(config_path) as config_file:

        colabconfig = json.load(config_file)

else:

    colabconfig = {"server_type": "generic"} # Usar la configura default si no existe

    with open(config_path, 'w') as new_config_file:

        json.dump(colabconfig, new_config_file)



# Instalar OpenJDK


version = colabconfig["server_version"]

if colabconfig["server_version"] < "1.17":

    # !sudo apt-get purge openjdk* > /dev/null 2>&1

    # !sudo apt-get install openjdk-8-jre-headless &>/dev/null and print("OpenJDK 8 instalado!") or print("Error al intalar OpenJDK 8.")

else:

    # !sudo apt-get purge openjdk* > /dev/null 2>&1

    # !sudo apt-get install openjdk-17-jre-headless &>/dev/null and print("OpenJDK 17 instalado!") or print("Error al intalar OpenJDK 17.")


# Chequeo de version de java

java_ver = !java -version 2>&1 | awk -F[\"\.] -v OFS=. 'NR==1{print $2}'

if java_ver[0] == "17":

    print("Estas usando JAVA 17.")

else:

    print("Estas usando una version desactualizada de java. Puedo que Minecraft 1.17+ no funcione.")



#Lista de posibles archivos .jar


jar_list = {'paper': 'server.jar', 'fabric': 'fabric-server-launch.jar', 'generic': 'server.jar', 'forge': 'forge.jar', 'vanilla': 'vanilla.jar', 'snapshot': 'snapshot.jar', 'mohist': "mohist.jar"}

jar_name = jar_list[colabconfig["server_type"]]



# Java arguments.

if colabconfig["server_type"] == "paper":

    server_flags = "-XX:+UseG1GC -XX:+ParallelRefProcEnabled -XX:MaxGCPauseMillis=200 -XX:+UnlockExperimentalVMOptions -XX:+DisableExplicitGC -XX:+AlwaysPreTouch -XX:G1NewSizePercent=30 -XX:G1MaxNewSizePercent=40 -XX:G1HeapRegionSize=8M -XX:G1ReservePercent=20 -XX:G1HeapWastePercent=5 -XX:G1MixedGCCountTarget=4 -XX:InitiatingHeapOccupancyPercent=15 -XX:G1MixedGCLiveThresholdPercent=90 -XX:G1RSetUpdatingPauseTimePercent=5 -XX:SurvivorRatio=32 -XX:+PerfDisableSharedMem -XX:MaxTenuringThreshold=1 -Dusing.aikars.flags=https://mcflags.emc.gs -Daikars.new.flags=true"

else:

    server_flags = "" # No se necesitan banderas para servidores que no sean de paper

#Argumentos JVM

memory_allocation = "-Xms10G -Xmx10G"



# Elige el servicio de tunelacion que desees

# Opciones disponibles: ngrok

tunnel_service = "ngrok"

print("Usando", tunnel_service)


#Condicional de tunelacion del servidor



if tunnel_service == "ngrok":

    # !pip -q install pyngrok #Aqui se instala el ngrok en el servidor

    from pyngrok import conf, ngrok



    # Obten tu token de ngrok

    print("Consigue tu authtoken de https://dashboard.ngrok.com/auth") #Consigue aqui tu token de ngrok, sera dinamico, si quieres que sea estatico, necesitaras la version premiun de ngrok

    import getpass



    # v - - - - - - - TOKEN - - - - - - - v



    authtoken = "2d9EA66tFCDwlgVSU1PxKK8MVSl_4u8J7aAoxsmvekF7RpZhk" # <---- TOKEN NGROK (PON AQUÍ TU TOKEN [TIENE QUE ESTAR ENTRE LAS "COMILLAS"])

    ! ngrok authtoken $authtoken # logeo en ngrok



    #Establecimiento de region de ngrok



    #v - - - - - - - REGIONES DISPONIBLES - - - - - - - v

    # ap - Asia/Pacifico (Singapore)

    # au - Australia (Sydney)

    # eu - Europa (Frankfurt - Alemania)

    # in - India (Mumbai)

    # jp - Japon (Tokyo)

    # sa - America del sur (São Paulo - Brasil)

    # us - Estados unidos (Ohio)

    conf.get_default().region = 'us' # <--- Cambia esto por la region que quieras



    # Conectar a ngrok

    url = ngrok.connect(25565, 'tcp')

    print('La IP de tu servidor es ' + ((str(url).split('"')[1::2])[0]).replace('tcp://', ''))

    #Si obtienes el servicio premiun de ngrok borra las dos lineas de codigo de arriba y quitale el # a estas a continuacion:

    #subdominio = "mi-subdominio"

    #url = ngrok.connect(25565, 'tcp', subdomain=subdominio)

    #print('La IP de tu servidor es ' + url.replace('tcp://', ''))



print('Iniciando servidor...')

def get_users():
    url = 'https://jsonplaceholder.typicode.com/users'
    try:
        response = requests.get(url)
        if response.status_code == 200:
            data = response.json()
            print("Lista de usuarios:")
            for user in data:
                print(f"Nombre: {user['name']}, Email: {user['email']}")
        else:
            print(f"Error al hacer la solicitud. Código de estado: {response.status_code}")
    except requests.RequestException as e:
        print(f"Error de conexión: {e}")

# Función para ejecutar get_users() cada 25 minutos
def repeat_get_users():
    while True:
        get_users()
        time.sleep(600)  # Espera 10 minutos

# Inicia un hilo para ejecutar repeat_get_users() en segundo plano
user_thread = threading.Thread(target=repeat_get_users)
user_thread.start()

if colabconfig["server_type"] == "forge":

    version = colabconfig["server_version"]

    if colabconfig["server_version"] < "1.17":

        oldpathtoforge = glob.glob(f"/workspaces/codespaces-jupyter/Minecraft-server/forge-{version}-*.jar")

        if oldpathtoforge: # Checa si la lista no esta vacia

            path = oldpathtoforge[0] # Obtiene la primera ruta de la lista

            print(path)

            # !java $memory_allocation -jar "{path}" nogui

        else:

            print("No se encontro la version de Forge universal.")

    else:

        pathtoforge = glob.glob(f"/workspaces/codespaces-jupyter/Minecraft-server/libraries/net/minecraftforge/forge/{version}-/unix_.txt")

        if pathtoforge: # Checa si la lista no esta vacia

            path = pathtoforge[0] # Obtiene la primera ruta de la lista

            print(path)

            # !java @user_jvm_args.txt "@{path}" "$@"

        else:

            print("No unix_args.txt found.")
else:

    # !java $memory_allocation $server_flags -jar $jar_name nogui



# Ciclo para realizar las solicitudes a JSONPlaceholder cada minutos

while True:
    time.sleep(60)
# Out:
# el apt cache fue actualizado correctamente
# banned-ips.json      forge.jar	    mohist-config    server-icon.png
# banned-players.json  forge.jar.log  mohist.jar	     server.properties
# bukkit.yml	     help.yml	    ops.json	     spigot.yml
# colabconfig.json     journeymap     patchouli_books  user_jvm_args.txt
# commands.yml	     libraries	    permissions.yml  usercache.json
# config		     logs	    plugins	     usernamecache.json
# defaultconfigs	     modernfix	    run.bat	     whitelist.json
# eula.txt	     mods	    run.sh	     world
# /bin/bash: -c: line 0: syntax error near unexpected token `('
# /bin/bash: -c: line 0: `sudo apt-get install openjdk-17-jre-headless &>/dev/null and print("OpenJDK 17 instalado!") or print("Error al intalar OpenJDK 17.")'
# Estas usando una version desactualizada de java. Puedo que Minecraft 1.17+ no funcione.
# Usando ngrok
# Consigue tu authtoken de https://dashboard.ngrok.com/auth
# Authtoken saved to configuration file: /home/codespace/.config/ngrok/ngrok.yml
# La IP de tu servidor es 0.tcp.ngrok.io:14378
# Iniciando servidor...
# Lista de usuarios:
# Nombre: Leanne Graham, Email: Sincere@april.biz
# Nombre: Ervin Howell, Email: Shanna@melissa.tv
# Nombre: Clementine Bauch, Email: Nathan@yesenia.net
# Nombre: Patricia Lebsack, Email: Julianne.OConner@kory.org
# Nombre: Chelsey Dietrich, Email: Lucio_Hettinger@annie.ca
# Nombre: Mrs. Dennis Schulist, Email: Karley_Dach@jasper.info
# Nombre: Kurtis Weissnat, Email: Telly.Hoeger@billy.biz
# Nombre: Nicholas Runolfsdottir V, Email: Sherwood@rosamond.me
# Nombre: Glenna Reichert, Email: Chaim_McDermott@dana.io
# Nombre: Clementina DuBuque, Email: Rey.Padberg@karina.biz
#
#  ███╗   ███╗  ██████╗  ██╗  ██╗ ██╗ ███████╗ ████████╗
#  ████╗ ████║ ██╔═══██╗ ██║  ██║ ██║ ██╔════╝ ╚══██╔══╝
#  ██╔████╔██║ ██║   ██║ ███████║ ██║ ███████╗    ██║
#  ██║╚██╔╝██║ ██║   ██║ ██╔══██║ ██║ ╚════██║    ██║
#  ██║ ╚═╝ ██║ ╚██████╔╝ ██║  ██║ ██║ ███████║    ██║
#  ╚═╝     ╚═╝  ╚═════╝  ╚═╝  ╚═╝ ╚═╝ ╚══════╝    ╚═╝
#
#
# Thanks for using Mohist - 1.20.1-580, Java(21.0.2) 65.0 PID: 3623
#
# Update in check...
# If you don't want to enable update check, set check_update in mohist-config/mohist.yml to false
# The latest Mohist version is 1.20.1-589 but you have 1.20.1-580. The latest version has been built on 2024-03-01 14:11:23. You should update to fix recent bugs!
# Checking libraries, please wait...
# All libraries are nice :)!
# Searching incompatible mods...
# [01:21:31 INFO]: ModLauncher running: args [--launchTarget, forgeserver, --fml.forgeVersion, 47.2.20, --fml.mcVersion, 1.20.1, --fml.forgeGroup, net.minecraftforge, --fml.mcpVersion, 20230612.114412, nogui]
# [01:21:31 INFO]: ModLauncher 10.0.9+10.0.9+main.dcd20f30 starting: java version 21.0.2 by Microsoft; OS Linux arch amd64 version 6.2.0-1019-azure
# [01:21:44 INFO]: ImmediateWindowProvider not loading because launch target is forgeserver
# [01:21:44 INFO]: SpongePowered MIXIN Subsystem Version=0.8.5 Source=union:/workspaces/codespaces-jupyter/Minecraft-server/libraries/org/spongepowered/mixin/0.8.5/mixin-0.8.5.jar%23111!/ Service=ModLauncher Env=SERVER
# [01:21:45 WARN]: Attempted to select two dependency jars from JarJar which have the same identification: Mod File:  and Mod File: . Using Mod File:
# [01:21:45 WARN]: Attempted to select a dependency jar for JarJar which was passed in as source: aeroblender. Using Mod File: /workspaces/codespaces-jupyter/Minecraft-server/mods/aeroblender-1.20.1-1.0.1-neoforge.jar
# [01:21:45 WARN]: Attempted to select a dependency jar for JarJar which was passed in as source: curios. Using Mod File: /workspaces/codespaces-jupyter/Minecraft-server/mods/curios-forge-5.7.0+1.20.1.jar
# [01:21:45 INFO]: Found 20 dependencies adding them to mods collection
# [01:21:48 INFO]: Compatibility level set to JAVA_17
# [01:21:49 INFO]: Successfully loaded Mixin Connector [com.sonicether.soundphysics.MixinConnector]
# [01:21:49 INFO]: Launching target 'forgeserver' with arguments [nogui]
# [01:21:49 INFO]: Loaded Saturn config file with 4 configurable options
# [01:21:49 WARN]: Reference map 'createdeco-common-refmap.json' for createdeco-common.mixins.json could not be read. If this is a development environment you can ignore this message
# [01:21:49 WARN]: Reference map 'createdeco-forge-refmap.json' for createdeco.mixins.json could not be read. If this is a development environment you can ignore this message
# [01:21:49 INFO]: Loaded configuration file for ModernFix 5.13.0+mc1.20.1: 74 options available, 0 override(s) found
# [01:21:49 INFO]: Applying Nashorn fix
# [01:21:49 INFO]: Applied Forge config corruption patch
# [01:21:49 INFO]: OptiFine was NOT detected.
# [01:21:49 INFO]: OptiFabric was NOT detected.
# [01:21:49 INFO]: Loaded configuration file for Embeddium: 191 options available, 0 override(s) found
# [01:21:49 WARN]: Reference map 'morevillagers-forge-forge-refmap.json' for morevillagers.mixins.json could not be read. If this is a development environment you can ignore this message
# [01:21:49 WARN]: Reference map 'tempad-forge-1.20.1-forge-refmap.json' for tempad.mixins.json could not be read. If this is a development environment you can ignore this message
# [01:21:49 WARN]: Reference map 'CreateLiquidFuel.refmap.json' for createliquidfuel.mixins.json could not be read. If this is a development environment you can ignore this message
# [01:21:49 WARN]: Reference map 'nitrogen_internals.refmap.json' for nitrogen_internals.mixins.json could not be read. If this is a development environment you can ignore this message
# [01:21:49 WARN]: Reference map 'trashslot.refmap.json' for trashslot.mixins.json could not be read. If this is a development environment you can ignore this message
# [01:21:49 WARN]: Reference map 'simplyswords-forge-refmap.json' for simplyswords.mixins.json could not be read. If this is a development environment you can ignore this message
# [01:21:49 INFO]: Loading 147 mods:
# 	- ad_astra 1.15.18
# 	- aeroblender 1.20.1-1.0.1-neoforge
# 	- aether 1.20.1-1.2.0-neoforge
# 	- aiimprovements 0.5.2
# 	- architectury 9.2.14
# 	- ars_elemental 1.20.1-0.6.4.1
# 	- ars_nouveau 4.9.0
# 	- artifacts 9.2.2
# 	- athena 3.1.1
# 	- attributeslib 1.2.1
# 	- balm 7.2.2
# 	- blockui 1.20.1-1.0.139-BETA
# 	- blue_skies 1.3.31
# 	- bookshelf 20.1.9
# 	- born_in_chaos_v1 1.0.0
# 	- botania 1.20.1-443-FORGE
# 	- botarium 2.3.3
# 	- buildinggadgets2 1.0.6
# 	- caelus 3.1.0+1.20
# 	- cfm 7.0.0-pre36
# 	- cloth_config 11.1.118
# 	- clumps 12.0.0.3
# 	- configured 2.2.2
# 	- constructionwand 1.20.1-2.11
# 	- corpse 1.20.1-1.0.9
# 	- cosmeticarmorreworked 1.20.1-v1a
# 	- create 0.5.1.f
# 	- create_dragon_lib 1.3.3
# 	- create_enchantment_industry 1.2.8
# 	- create_sa 2.0.4.
# 	- create_ultimate_factory 1.5.0
# 	- createaddition 1.20.1-1.2.3
# 	- createarmory 0.5
# 	- createdeco 2.0.1-1.20.1-forge
# 	- createliquidfuel 2.1.0-1.20.1
# 	- createoreexcavation 1.4.2
# 	- cristellib 1.1.5
# 	- cumulus_menus 1.20.1-1.0.0-neoforge
# 	- cupboard 1.20.1-2.3
# 	- curios 5.7.0+1.20.1
# 	- cyclopscore 1.19.0
# 	- darkmodeeverywhere 1.20.1-1.2.2
# 	- deep_aether 1.20.1-1.0.2
# 	- deeperdarker 1.2.1
# 	- dimdungeons 191
# 	- domum_ornamentum 1.20-1.0.160-BETA
# 	- elevatorid 1.20.1-lex-1.9
# 	- elytraslot 6.3.0+1.20.1
# 	- embeddium 0.3.7+mc1.20.1
# 	- enchdesc 17.0.14
# 	- endersdelight 1.0.3
# 	- ends_delight 1.0.1
# 	- entityculling 1.6.2
# 	- evilcraft 1.2.37
# 	- evilcraftcompat 1.2.37
# 	- expandability 9.0.0
# 	- farmersdelight 1.20.1-1.2.4
# 	- fastleafdecay 31
# 	- ferritecore 6.0.1
# 	- flywheel 0.6.10-7
# 	- forge 47.2.20
# 	- fpsreducer 1.20-2.5
# 	- framework 0.6.26
# 	- fusion 1.1.1
# 	- gateways 4.2.3
# 	- geckolib 4.3.1
# 	- goblintraders 1.9.3
# 	- gpumemleakfix 1.20.1-1.8
# 	- immersive_armors 1.6.1+1.20.1
# 	- integrated_api 1.3.7+1.20.1-forge
# 	- inventoryhud 3.4.18
# 	- ironchest 1.20.1-14.4.4
# 	- ironfurnaces 4.1.4
# 	- irons_spellbooks 1.20.1-3.0.1
# 	- jade 11.8.0
# 	- jadeaddons 5.2.2
# 	- jei 15.3.0.4
# 	- jeresources 1.4.0.247
# 	- jet_and_elias_armors 1.0.0
# 	- journeymap 5.9.18
# 	- justenoughdrugz 1.1.10
# 	- justzoom 1.0.2
# 	- konkrete 1.8.0
# 	- l2library 2.4.16
# 	- lootr 0.7.31.77
# 	- lost_aether_content 1.2.3
# 	- maxhealthfix 12.0.2
# 	- mekanism 10.4.6
# 	- mekanismadditions 10.4.6
# 	- mekanismgenerators 10.4.6
# 	- mekanismtools 10.4.6
# 	- minecolonies 1.20.1-1.1.484-BETA
# 	- minecraft 1.20.1
# 	- mixinextras 0.2.0-beta.9
# 	- modernfix 5.13.0+mc1.20.1
# 	- mohist 1.20.1
# 	- morevillagers 5.0.0
# 	- mousetweaks 2.25
# 	- mutantmonsters 8.0.7
# 	- nethersdelight 1.20.1-4.0
# 	- nitrogen_internals 1.20.1-1.0.2-neoforge
# 	- notenoughanimations 1.7.1
# 	- patchouli 1.20.1-84-FORGE
# 	- pipez 1.20.1-1.2.5
# 	- placebo 8.6.1
# 	- playeranimator 1.0.2-rc1+1.20
# 	- polymorph 0.49.2+1.20.1
# 	- productivebees 1.20.1-12.3.1
# 	- productivelib 1.20.1-0.0.1
# 	- puzzlesaccessapi 8.0.7
# 	- puzzleslib 8.1.17
# 	- railways 1.5.3+forge-mc1.20.1
# 	- rechiseled 1.1.5c
# 	- rechiseledcreate 1.0.2
# 	- refinedstorage 1.12.3
# 	- resourcefulconfig 2.1.2
# 	- resourcefullib 2.1.23
# 	- rubidium 0.7.1
# 	- saturn 0.1.3
# 	- securitycraft 1.9.8
# 	- shieldexp 1.1.7a
# 	- simplehats 1.20.1-0.2.2
# 	- simplyswords 1.54.0-1.20.1
# 	- smoothchunk 1.20.1-3.6
# 	- sound_physics_remastered 1.20.1-1.1.2
# 	- spark 1.10.53
# 	- spectrelib 0.13.14+1.20.1
# 	- storagedrawers 12.0.2
# 	- structure_gel 2.16.0
# 	- structurize 1.20.1-1.0.699-BETA
# 	- supermartijn642configlib 1.1.8
# 	- supermartijn642corelib 1.1.17
# 	- t_and_t 0.0NONE
# 	- tempad 2.3.3
# 	- terrablender 3.0.1.4
# 	- terralith 2.4.11
# 	- the_bumblezone 7.2.15+1.20.1-forge
# 	- toolbelt 1.20.0
# 	- trashslot 15.1.0
# 	- travelersbackpack 9.1.12
# 	- travelerstitles 1.20-Forge-4.0.2
# 	- twigs 1.20.1-3.1.1
# 	- twilightdelight 2.0.7
# 	- twilightforest 4.3.2145
# 	- voidtotem 3.0.1
# 	- waystones 14.1.3
# 	- yungsapi 1.20-Forge-4.0.4
# [01:21:49 WARN]: Reference map 'cristellib-forge-refmap.json' for cristellib.mixins.json could not be read. If this is a development environment you can ignore this message
# [01:21:51 INFO]: Patching IForgeItemStack#getEnchantmentLevel
# [01:21:51 INFO]: Patching IForgeItemStack#getEnchantmentLevel
# [01:21:51 WARN]: Error loading class: de/maxhenkel/voicechat/plugins/impl/audiochannel/EntityAudioChannelImpl (java.lang.ClassNotFoundException: de.maxhenkel.voicechat.plugins.impl.audiochannel.EntityAudioChannelImpl)
# [01:21:51 WARN]: @Mixin target de.maxhenkel.voicechat.plugins.impl.audiochannel.EntityAudioChannelImpl was not found railways-common.mixins.json:compat.voicechat.EntityAudioChannelImplMixin
# [01:21:51 WARN]: Error loading class: de/maxhenkel/voicechat/voice/server/Server (java.lang.ClassNotFoundException: de.maxhenkel.voicechat.voice.server.Server)
# [01:21:51 WARN]: @Mixin target de.maxhenkel.voicechat.voice.server.Server was not found railways-common.mixins.json:compat.voicechat.ServerMixin
# [01:21:51 WARN]: Error loading class: de/maxhenkel/voicechat/voice/server/ServerWorldUtils (java.lang.ClassNotFoundException: de.maxhenkel.voicechat.voice.server.ServerWorldUtils)
# [01:21:51 WARN]: @Mixin target de.maxhenkel.voicechat.voice.server.ServerWorldUtils was not found railways-common.mixins.json:compat.voicechat.ServerWorldUtilsMixin
# [01:21:52 WARN]: Error loading class: net/minecraft/client/renderer/entity/PhantomRenderer (java.lang.ClassNotFoundException: net.minecraft.client.renderer.entity.PhantomRenderer)
# [01:21:52 WARN]: @Mixin target net.minecraft.client.renderer.entity.PhantomRenderer was not found mixins.deeperdarker.json:PhantomRendererMixin
# [01:21:52 WARN]: Error loading class: com/mojang/blaze3d/audio/Channel (java.lang.ClassNotFoundException: com.mojang.blaze3d.audio.Channel)
# [01:21:52 WARN]: @Mixin target com.mojang.blaze3d.audio.Channel was not found assets/sound_physics_remastered/sound_physics_remastered.mixins.json:ChannelAccessor
# [01:21:53 INFO]: Initializing MixinExtras via com.llamalad7.mixinextras.service.MixinExtrasServiceImpl(version=0.3.2).
# [01:21:53 INFO]: ModernFix reached bootstrap stage (32.09 s after launch)
# [01:21:54 INFO]: Patching IForgeItemStack#getEnchantmentLevel
# [01:21:54 INFO]: Patching IForgeItemStack#getEnchantmentLevel
# [01:21:56 INFO]: Vanilla bootstrap took 2408 milliseconds
# [01:21:56 WARN]: @Redirect conflict. Skipping securitycraft.mixins.json:camera.ServerPlayerMixin->@Redirect::securitycraft$tick(Lnet/minecraft/server/level/ServerPlayer;DDDFF)V with priority 1100, already redirected by railways-common.mixins.json:conductor_possession.ServerPlayerMixin->@Redirect::snr$securitycraft$tick(Lnet/minecraft/server/level/ServerPlayer;DDDFF)V with priority 1200
# [01:21:57 INFO]: Patching IForgeItemStack#getEnchantmentLevel
# [01:21:57 INFO]: Patching IForgeItemStack#getEnchantmentLevel
# [01:21:59 WARN]: Static binding violation: PRIVATE @Overwrite method m_47505_ in modernfix-common.mixins.json:perf.remove_biome_temperature_cache.BiomeMixin cannot reduce visibiliy of PUBLIC target method, visibility will be upgraded.
# [01:21:59 WARN]: Method overwrite conflict for m_47505_ in modernfix-common.mixins.json:perf.remove_biome_temperature_cache.BiomeMixin, previously written by com.abdelaziz.saturn.mixin.leaks.biome_temperature_cache.BiomeMixin. Skipping method.
# [01:22:05 INFO]: Attempting to load the Modding Legacy supporters list from https://moddinglegacy.com/supporters-changelogs/supporters.txt
# [01:22:05 INFO]: Registering items for Create Deco
# [01:22:05 INFO]: Successfully loaded the Modding Legacy supporters list.
# [01:22:05 INFO]: Registering blocks for Create Deco
# [01:22:05 INFO]: Loaded maxhealthfix for Forge.
# [01:22:05 INFO]: Create: Dragon Lib 1.3.3 has initialized, ready to support your Create add-ons!
# [01:22:05 INFO]: Fixing MC-151457. Crafting remainder for minecraft:pufferfish_bucket is now minecraft:bucket.
# [01:22:05 INFO]: Fixing MC-151457. Crafting remainder for minecraft:salmon_bucket is now minecraft:bucket.
# [01:22:05 INFO]: Fixing MC-151457. Crafting remainder for minecraft:cod_bucket is now minecraft:bucket.
# [01:22:05 INFO]: Fixing MC-151457. Crafting remainder for minecraft:tropical_fish_bucket is now minecraft:bucket.
# [01:22:05 INFO]: Fixing MC-151457. Crafting remainder for minecraft:axolotl_bucket is now minecraft:bucket.
# [01:22:05 INFO]: Fixing MC-151457. Crafting remainder for minecraft:powder_snow_bucket is now minecraft:bucket.
# [01:22:05 INFO]: Fixing MC-151457. Crafting remainder for minecraft:tadpole_bucket is now minecraft:bucket.
# [01:22:06 INFO]: [KONKRETE] Successfully initialized!
# [01:22:06 INFO]: [KONKRETE] Server-side libs ready to use!
# [01:22:06 ERROR]: Attempted to load class net/minecraft/client/Minecraft for invalid dist DEDICATED_SERVER
# [01:22:06 ERROR]: Failed to update fingerprint
# java.lang.NoClassDefFoundError: net/minecraft/client/Minecraft
# 	at me.jellysquid.mods.sodium.client.data.fingerprint.FingerprintMeasure.create(FingerprintMeasure.java:19) ~[embeddium-0.3.7+mc1.20.1.jar%23367!/:?]
# 	at me.jellysquid.mods.sodium.client.SodiumClientMod.updateFingerprint(SodiumClientMod.java:100) ~[embeddium-0.3.7+mc1.20.1.jar%23367!/:?]
# 	at me.jellysquid.mods.sodium.client.SodiumClientMod.<init>(SodiumClientMod.java:41) ~[embeddium-0.3.7+mc1.20.1.jar%23367!/:?]
# 	at jdk.internal.reflect.DirectConstructorHandleAccessor.newInstance(DirectConstructorHandleAccessor.java:62) ~[?:?]
# 	at java.lang.reflect.Constructor.newInstanceWithCaller(Constructor.java:502) ~[?:?]
# 	at java.lang.reflect.Constructor.newInstance(Constructor.java:486) ~[?:?]
# 	at net.minecraftforge.fml.javafmlmod.FMLModContainer.constructMod(FMLModContainer.java:76) ~[javafmllanguage-1.20.1-47.2.20.jar%23454!/:?]
# 	at net.minecraftforge.fml.ModContainer.lambda$buildTransitionHandler$10(ModContainer.java:123) ~[fmlcore-1.20.1-47.2.20.jar%23453!/:?]
# 	at java.util.concurrent.CompletableFuture$AsyncRun.run(CompletableFuture.java:1804) [?:?]
# 	at java.util.concurrent.CompletableFuture$AsyncRun.exec(CompletableFuture.java:1796) [?:?]
# 	at java.util.concurrent.ForkJoinTask.doExec(ForkJoinTask.java:387) [?:?]
# 	at java.util.concurrent.ForkJoinPool$WorkQueue.topLevelExec(ForkJoinPool.java:1312) [?:?]
# 	at java.util.concurrent.ForkJoinPool.scan(ForkJoinPool.java:1843) [?:?]
# 	at java.util.concurrent.ForkJoinPool.runWorker(ForkJoinPool.java:1808) [?:?]
# 	at java.util.concurrent.ForkJoinWorkerThread.run(ForkJoinWorkerThread.java:188) [?:?]
# Caused by: java.lang.ClassNotFoundException: net.minecraft.client.Minecraft
# 	at cpw.mods.cl.ModuleClassLoader.loadClass(ModuleClassLoader.java:157) ~[securejarhandler-mohist-2.1.11.jar:?]
# 	at java.lang.ClassLoader.loadClass(ClassLoader.java:526) ~[?:?]
# 	... 15 more
# [01:22:06 INFO]: Found 0 RS API injection points
# [01:22:07 INFO]: Initializing Update Checker...
# [01:22:07 INFO]: Starting Update Check...
# [01:22:07 INFO]: Update Check done!
# [01:22:07 INFO]: Iron Furnaces is up to date!
# [01:22:07 INFO]: Registered bogey styles from railways
# [01:22:07 INFO]: Loaded 238 hat entries from simplehats.json
# [01:22:07 INFO]: Registering data fixers
# [01:22:07 INFO]: Disabling Cumulus as it is on server.
# [01:22:08 INFO]: Bypassed Mojang DFU
# [01:22:08 INFO]: Instantiating Mojang DFU
# [01:22:08 INFO]: Loaded config for: cupboard.json
# [01:22:08 INFO]: Registering C2S receiver with id architectury:sync_ids
# [01:22:08 INFO]: Loading up Void Totem (Forge)
# [01:22:08 INFO]: Deep Aether: Registering Aether Lost Content compat items
# [01:22:08 INFO]: Deep Aether: Registering Aether Lost Content compat items
# [01:22:08 INFO]: Constructing common components for mutantmonsters:main
# [01:22:09 INFO]: 0 Datafixer optimizations took 0 milliseconds
# [01:22:09 INFO]: Registering C2S receiver with id artifacts:networking_channel/42a7ad70b1cc371599a0eff744096b8a
# [01:22:09 INFO]: Registering C2S receiver with id artifacts:networking_channel/74a5e841822a3a87854ae896a33430d6
# [01:22:09 INFO]: Registering C2S receiver with id artifacts:networking_channel/eb3d1e2748533430848cadf0f37c7e9c
# [01:22:09 INFO]: Registering C2S receiver with id artifacts:networking_channel/91c8520f19f93b3e8b6a727568e194ab
# [01:22:09 INFO]: Registering C2S receiver with id artifacts:networking_channel/8c2784d778293fd482ed84b8aa5fedb9
# [01:22:09 INFO]: Registering tracks for Hex Casting
# [01:22:09 INFO]: Registering tracks for Oh The Biomes You'll Go
# [01:22:09 INFO]: Registering tracks for Blue Skies
# [01:22:09 INFO]: Registering tracks for Twilight Forest
# [01:22:09 INFO]: Mohist mod loading.....
# [01:22:09 INFO]: Registering tracks for Biomes O' Plenty
# [01:22:09 INFO]: EventDispatcherRegistry initialized
# [01:22:09 INFO]: Forge mod loading, version 47.2.20, for MC 1.20.1 with MCP 20230612.114412
# [01:22:09 INFO]: MinecraftForge v47.2.20 Initialized
# [01:22:09 INFO]: NeoForge v47.2.20 Initialized
# [Mouse Tweaks] Disabled because not running on the client.
# /workspaces/codespaces-jupyter/Minecraft-server/config
# [01:22:11 INFO]: Registered structure pack: Warped Netherlands
# [01:22:11 ERROR]: -----------------------------------------------------------------
#  Invalid DataFixer detected, schematics might not paste correctly!
# The following DataFixer was added: class org.embeddedt.modernfix.dfu.LazyDataFixer
# -----------------------------------------------------------------
# [01:22:11 INFO]: Registered structure pack: Stalactite Caves
# [01:22:11 INFO]: Registered structure pack: Space Wars
# [01:22:11 INFO]: Registered structure pack: Shire
# [01:22:11 INFO]: Registered structure pack: Desert Oasis
# [01:22:11 INFO]: Registered structure pack: Pagoda
# [01:22:11 INFO]: Registered structure pack: Minecolonies Original
# [01:22:11 INFO]: Registered structure pack: Nordic Spruce
# [01:22:11 INFO]: Registered structure pack: Medieval Spruce
# [01:22:11 INFO]: Registered structure pack: Medieval Oak
# [01:22:11 INFO]: Registered structure pack: Medieval Dark Oak
# [01:22:11 INFO]: Registered structure pack: Medieval Birch
# [01:22:11 INFO]: Registered structure pack: Lost Mesa City
# [01:22:11 INFO]: Registered structure pack: Jungle Treehouse
# [01:22:11 INFO]: Registered structure pack: Incan
# [01:22:11 INFO]: Registered structure pack: Fortress
# [01:22:11 INFO]: Registered structure pack: Dark Oak Treehouse
# [01:22:11 INFO]: Registered structure pack: Colonial
# [01:22:11 INFO]: Registered structure pack: Cavern
# [01:22:11 INFO]: Registered structure pack: Caledonia
# [01:22:11 INFO]: Registered structure pack: Urban Birch
# [01:22:11 INFO]: Registered structure pack: Urban Savanna
# [01:22:11 WARN]: Failed loading packs from main folder path: .
# [01:22:11 WARN]: Failed loading client packs from main folder path: .
# [01:22:11 WARN]: Finished discovering Server Structure packs
# [01:22:11 INFO]: Constructing common components for puzzleslib:main
# [01:22:11 INFO]: ExpandAbility here, who dis?
# [01:22:16 INFO]: placard tooltip was null
# [01:22:16 INFO]: placard tooltip was null
# [01:22:16 INFO]: placard tooltip was null
# [01:22:16 INFO]: placard tooltip was null
# [01:22:16 INFO]: placard tooltip was null
# [01:22:16 INFO]: placard tooltip was null
# [01:22:16 INFO]: placard tooltip was null
# [01:22:16 INFO]: placard tooltip was null
# [01:22:16 INFO]: placard tooltip was null
# [01:22:16 INFO]: placard tooltip was null
# [01:22:16 INFO]: placard tooltip was null
# [01:22:16 INFO]: placard tooltip was null
# [01:22:16 INFO]: placard tooltip was null
# [01:22:16 INFO]: placard tooltip was null
# [01:22:16 INFO]: placard tooltip was null
# [01:22:16 INFO]: Generated 238 hat items from hat entries.
# [01:22:17 INFO]: 2205 possible Broom base combinations are ready for flying!
# [01:22:18 INFO]: [structure_gel] Registering data for structure_gel:loot_table_alias
# [01:22:18 INFO]: [structure_gel] Registering data for structure_gel:data_handler_type
# [01:22:18 INFO]: [structure_gel] Registering data for structure_gel:dynamic_spawner
# [01:22:18 INFO]: [structure_gel] Registering data for structure_gel:jigsaw_type
# [01:22:18 WARN]: Registry forge:global_loot_modifier_serializers: The object RecordCodec[UnitDecoder[vectorwing.farmersdelight.common.loot.modifier.AddItemModifier$$Lambda/0x00007fe37ed406a8@71cf6119] * Field[conditions: passthrough[flatXmapped]] * Field[item: net.minecraftforge.registries.ForgeRegistry$RegistryCodec@3e16dd6d] * OptionalFieldCodec[count: Int][xmapped]] has been registered twice for the same name farmersdelight:add_item.
# [01:22:18 WARN]: Registry forge:global_loot_modifier_serializers: The object RecordCodec[UnitDecoder[vectorwing.farmersdelight.common.loot.modifier.AddLootTableModifier$$Lambda/0x00007fe37ed40d50@6c607ffb] * Field[conditions: passthrough[flatXmapped]] * Field[lootTable: String[comapFlatMapped]]] has been registered twice for the same name farmersdelight:add_loot_table.
# [01:22:18 WARN]: Registry forge:global_loot_modifier_serializers: The object RecordCodec[UnitDecoder[vectorwing.farmersdelight.common.loot.modifier.PastrySlicingModifier$$Lambda/0x00007fe37ed413e8@15ef711b] * Field[conditions: passthrough[flatXmapped]] * Field[slice: net.minecraftforge.registries.ForgeRegistry$RegistryCodec@3e16dd6d]] has been registered twice for the same name farmersdelight:pastry_slicing.
# [01:22:18 INFO]: Please use /mfsrc to reload any changed mod config files
# [01:22:18 INFO]: Loading common config for mutantmonsters
# [01:22:18 INFO]: Loaded Create Ore Excavation config file createoreexcavation-common.toml
# [01:22:18 INFO]: gpumemleakfix mod initialized
# [01:22:18 INFO]: Registered packet handler.
# [01:22:19 INFO]: Reloading reverb parameters
# [01:22:19 INFO]: HELLO FROM PREINIT
# [01:22:19 INFO]: DIRT BLOCK >> translation{key='block.minecraft.dirt', args=[]}
# [01:22:19 INFO]: HELLO FROM PREINIT
# [01:22:19 INFO]: DIRT BLOCK >> translation{key='block.minecraft.dirt', args=[]}
# [01:22:19 WARN]: Sound event justenoughdrugz:bong_use not found
# [01:22:19 INFO]: ConstructionWand says hello - may the odds be ever in your favor.
# [01:22:19 INFO]: Botania integration added
# [01:22:19 INFO]: Version 10.4.6 initializing...
# [01:22:19 INFO]: Loaded 'Mekanism: Additions' module.
# [01:22:19 INFO]: Loaded 'Mekanism: Generators' module.
# [01:22:19 INFO]: Loaded 'Mekanism: Tools' module.
# THE_AETHER
# [OVERWORLD, NETHER, THE_AETHER]
# THE_AETHER
# THE_AETHER
# [OVERWORLD, NETHER, THE_AETHER]
# THE_AETHER
# [01:22:19 INFO]: Create Ore Excavation starting
# [01:22:19 INFO]: Initilaized Network Handler
# [01:22:19 INFO]: New compacting rule 4 clay_ball = 1 clay
# [01:22:19 INFO]: New compacting rule 4 snowball = 1 snow_block
# [01:22:19 INFO]: New compacting rule 4 glowstone_dust = 1 glowstone
# [01:22:19 INFO]: New compacting rule 4 brick = 1 bricks
# [01:22:19 INFO]: New compacting rule 4 nether_brick = 1 nether_bricks
# [01:22:19 INFO]: New compacting rule 9 nether_wart = 1 nether_wart_block
# [01:22:19 INFO]: New compacting rule 4 quartz = 1 quartz_block
# [01:22:19 INFO]: New compacting rule 9 melon_slice = 1 melon
# [01:22:19 INFO]: New compacting rule 4 sand = 1 sandstone
# [01:22:19 INFO]: New compacting rule 4 red_sand = 1 red_sandstone
# [01:22:19 INFO]: New compacting rule 4 clay_ball = 1 clay
# [01:22:19 INFO]: Fake player readout: UUID = 46e82cd0-d480-3d48-800a-77431ede078e, name = [Mekanism]
# [01:22:19 INFO]: Mod loaded.
# [01:22:19 INFO]: Registered region minecraft:overworld to index 0 for type OVERWORLD
# [01:22:19 INFO]: Registered region minecraft:nether to index 0 for type NETHER
# [01:22:19 INFO]: Registered region aether:the_aether to index 0 for type THE_AETHER
# [01:22:19 INFO]: Registered region deep_aether:deep_aether to index 1 for type THE_AETHER
# [01:22:19 INFO]: Registered the FluidEffect with Unique ID of minecraft:water for Water (Fluid Amount Required: 1000) with the ID 0
# [01:22:19 INFO]: Registered the FluidEffect with Unique ID of minecraft:lava for Lava (Fluid Amount Required: 1000) with the ID 1
# [01:22:19 INFO]: Registered the FluidEffect with Unique ID of travelersbackpack:potion for Uncraftable Potion (Fluid Amount Required: 250) with the ID 2
# [01:22:19 INFO]: Registered the FluidEffect with Unique ID of minecraft:milk for Milk (Fluid Amount Required: 1000) with the ID 3
# [01:22:19 INFO]: Initializing Packet Registries
# [01:22:19 INFO]: Registered region ars_nouveau:overworld to index 1 for type OVERWORLD
# [01:22:20 INFO]: Got IMC []
# Create Crafts & Additions Initialized!
# [01:22:20 WARN]: Register mappings
# [01:22:20 INFO]: Start loading plugin at com.aetherteam.aether.integration.jade.AetherJadePlugin
# [01:22:20 INFO]: Start loading plugin at dev.shadowsoffire.gateways.compat.GatewayJadePlugin
# [01:22:20 INFO]: Start loading plugin at twilightforest.compat.jade.JadeCompat
# [01:22:20 INFO]: Start loading plugin at de.maxhenkel.corpse.integration.waila.PluginCorpse
# [01:22:20 INFO]: Start loading plugin at cy.jdkdigital.productivebees.compat.hwyla.ProductiveBeesWailaPlugin
# [01:22:20 INFO]: Start loading plugin at snownee.jade.addon.lootr.LootrPlugin
# [01:22:20 INFO]: Start loading plugin at snownee.jade.addon.general.GeneralPlugin
# [01:22:20 INFO]: Start loading plugin at snownee.jade.addon.create.CreatePlugin
# [01:22:20 INFO]: Start loading plugin at mekanism.common.integration.lookingat.jade.MekanismJadePlugin
# [01:22:20 INFO]: Start loading plugin at net.blay09.mods.waystones.compat.JadeIntegration
# [01:22:20 INFO]: Start loading plugin at com.hollingsworth.arsnouveau.client.waila.WailaArsNouveauPlugin
# [01:22:20 INFO]: Start loading plugin at snownee.jade.addon.vanilla.VanillaPlugin
# [01:22:20 INFO]: Start loading plugin at snownee.jade.addon.universal.UniversalPlugin
# [01:22:20 INFO]: Start loading plugin at snownee.jade.addon.core.CorePlugin
# [01:22:20 INFO]: Start loading plugin at de.maxhenkel.pipez.integration.waila.PluginPipes
# [01:22:20 INFO]: Start loading plugin at net.geforcemods.securitycraft.compat.waila.JadeDataProvider
# [01:22:20 INFO]: Start loading plugin at com.jaquadro.minecraft.storagedrawers.integration.Waila
# [01:22:21 INFO]: Environment: authHost='https://authserver.mojang.com', accountsHost='https://api.mojang.com', sessionHost='https://sessionserver.mojang.com', servicesHost='https://api.minecraftservices.com', name='PROD'
# [01:22:22 ERROR]: Cristel Lib Config Pack has no data
# [01:22:22 WARN]: T&T Waystone Patch Pack accepted!
# [01:22:33 INFO]: Skipping loading recipe productivebees:expansion_boxes/expansion_box_byg_cypress as it's serializer returned null
# Finalizing energy item registration
# Finalizing fluid item registration
# [01:22:33 INFO]: Skipping loading recipe productivebees:expansion_boxes/expansion_box_atmospheric_kousa as it's serializer returned null
# [01:22:33 INFO]: Skipping loading recipe productivebees:hives/advanced_biomesoplenty_magic_beehive as it's serializer returned null
# [01:22:33 INFO]: Skipping loading recipe productivebees:hives/advanced_biomesoplenty_dead_beehive as it's serializer returned null
# [01:22:33 INFO]: Skipping loading recipe productivebees:hives/advanced_biomesoplenty_magic_beehive_clear as it's serializer returned null
# [01:22:33 INFO]: Skipping loading recipe productivebees:expansion_boxes/expansion_box_byg_palm as it's serializer returned null
# [01:22:33 INFO]: Skipping loading recipe productivebees:hives/advanced_upgrade_aquatic_driftwood_beehive_clear as it's serializer returned null
# [01:22:33 INFO]: Skipping loading recipe productivebees:hives/advanced_byg_bulbis_beehive_clear as it's serializer returned null
# [01:22:33 INFO]: Skipping loading recipe productivebees:hives/advanced_regions_unexplored_pink_bioshroom_beehive_clear as it's serializer returned null
# [01:22:33 INFO]: Skipping loading recipe productivebees:expansion_boxes/expansion_box_atmospheric_morado as it's serializer returned null
# [01:22:33 INFO]: Skipping loading recipe productivebees:corail/woodcutter/mahogany_canvas_expansion_box as it's serializer returned null
# [01:22:33 INFO]: Skipping loading recipe productivebees:corail/woodcutter/willow_canvas_expansion_box as it's serializer returned null
# [01:22:33 INFO]: Skipping loading recipe productivebees:expansion_boxes/expansion_box_regions_unexplored_magnolia as it's serializer returned null
# [01:22:33 INFO]: Skipping loading recipe productivebees:hives/advanced_byg_white_mangrove_beehive_clear as it's serializer returned null
# [01:22:33 INFO]: Skipping loading recipe productivebees:expansion_boxes/expansion_box_regions_unexplored_eucalyptus as it's serializer returned null
# [01:22:33 INFO]: Skipping loading recipe productivebees:hives/advanced_atmospheric_yucca_beehive_clear as it's serializer returned null
# [01:22:33 INFO]: Skipping loading recipe productivebees:corail/woodcutter/crimson_canvas_expansion_box as it's serializer returned null
# [01:22:33 INFO]: Skipping loading recipe productivebees:hives/advanced_regions_unexplored_redwood_beehive_clear as it's serializer returned null
# [01:22:33 INFO]: Skipping loading recipe productivebees:hives/advanced_endergetic_poise_beehive_clear as it's serializer returned null
# [01:22:33 INFO]: Skipping loading recipe productivebees:hives/advanced_regions_unexplored_maple_beehive_clear as it's serializer returned null
# [01:22:33 INFO]: Skipping loading recipe productivebees:corail/woodcutter/bamboo_canvas_hive as it's serializer returned null
# [01:22:33 INFO]: Skipping loading recipe productivebees:hives/advanced_regions_unexplored_palm_beehive_clear as it's serializer returned null
# [01:22:33 INFO]: Skipping loading recipe productivebees:hives/advanced_regions_unexplored_magnolia_beehive_clear as it's serializer returned null
# [01:22:33 INFO]: Skipping loading recipe productivebees:expansion_boxes/expansion_box_byg_lament as it's serializer returned null
# [01:22:33 INFO]: Skipping loading recipe productivebees:corail/woodcutter/warped_canvas_expansion_box as it's serializer returned null
# [01:22:33 INFO]: Skipping loading recipe productivebees:corail/woodcutter/jungle_canvas_expansion_box as it's serializer returned null
# [01:22:33 INFO]: Skipping loading recipe productivebees:corail/woodcutter/acacia_canvas_hive as it's serializer returned null
# [01:22:33 INFO]: Skipping loading recipe productivebees:expansion_boxes/expansion_box_quark_blossom as it's serializer returned null
# [01:22:33 INFO]: Skipping loading recipe productivebees:expansion_boxes/expansion_box_autumnity_maple as it's serializer returned null
# [01:22:33 INFO]: Skipping loading recipe toolbelt:pouch_upgrade_1_via_sewing as it's serializer returned null
# [01:22:33 INFO]: Skipping loading recipe productivebees:expansion_boxes/expansion_box_regions_unexplored_dead as it's serializer returned null
# [01:22:33 INFO]: Skipping loading recipe productivebees:hives/advanced_biomesoplenty_palm_beehive as it's serializer returned null
# [01:22:33 INFO]: Skipping loading recipe twilightforest:jeed/hunger as it's serializer returned null
# [01:22:33 INFO]: Skipping loading recipe productivebees:hives/advanced_upgrade_aquatic_river_beehive_clear as it's serializer returned null
# [01:22:33 INFO]: Skipping loading recipe productivebees:hives/advanced_byg_witch_hazel_beehive_clear as it's serializer returned null
# [01:22:33 WARN]: Your custom createaddition:rolling/brass_ingot recipe (createaddition:rolling/brass_ingot) specified a duration. Durations have no impact on this type of recipe.
# [01:22:33 INFO]: Skipping loading recipe productivebees:hives/advanced_regions_unexplored_blue_bioshroom_beehive as it's serializer returned null
# [01:22:33 INFO]: Skipping loading recipe productivebees:expansion_boxes/expansion_box_byg_jacaranda as it's serializer returned null
# [01:22:33 INFO]: Skipping loading recipe productivebees:hives/advanced_byg_mahogany_beehive as it's serializer returned null
# [01:22:33 INFO]: Skipping loading recipe productivebees:hives/advanced_biomesoplenty_palm_beehive_clear as it's serializer returned null
# [01:22:33 INFO]: Skipping loading recipe productivebees:hives/advanced_byg_jacaranda_beehive as it's serializer returned null
# [01:22:33 INFO]: Skipping loading recipe productivebees:corail/woodcutter/snake_block_canvas_expansion_box as it's serializer returned null
# [01:22:33 INFO]: Skipping loading recipe productivebees:hives/advanced_biomesoplenty_hellbark_beehive_clear as it's serializer returned null
# [01:22:33 INFO]: Skipping loading recipe productivebees:hives/advanced_byg_cypress_beehive_clear as it's serializer returned null
# [01:22:33 INFO]: Skipping loading recipe productivebees:hives/advanced_biomesoplenty_hellbark_beehive as it's serializer returned null
# [01:22:33 INFO]: Skipping loading recipe productivebees:expansion_boxes/expansion_box_regions_unexplored_pine as it's serializer returned null
# [01:22:33 INFO]: Skipping loading recipe productivebees:hives/advanced_regions_unexplored_blackwood_beehive as it's serializer returned null
# [01:22:33 INFO]: Skipping loading recipe productivebees:expansion_boxes/expansion_box_biomesoplenty_redwood as it's serializer returned null
# [01:22:33 INFO]: Skipping loading recipe productivebees:hives/advanced_regions_unexplored_willow_beehive_clear as it's serializer returned null
# [01:22:33 INFO]: Skipping loading recipe ars_elemental:jeed/life_link as it's serializer returned null
# [01:22:33 WARN]: Your custom createaddition:rolling/copper_ingot recipe (createaddition:rolling/copper_ingot) specified a duration. Durations have no impact on this type of recipe.
# [01:22:33 INFO]: Skipping loading recipe productivebees:expansion_boxes/expansion_box_byg_baobab as it's serializer returned null
# [01:22:33 ERROR]: Parsing error loading recipe railways:sequenced_assembly/track_blue_skies_cherry_wide: com.google.gson.JsonSyntaxException: Unknown item 'blue_skies:cherry_slab'
# [01:22:33 INFO]: Skipping loading recipe productivebees:corail/woodcutter/spruce_canvas_hive as it's serializer returned null
# [01:22:33 INFO]: Skipping loading recipe productivebees:expansion_boxes/expansion_box_regions_unexplored_socotra as it's serializer returned null
# [01:22:33 INFO]: Skipping loading recipe productivebees:hives/advanced_byg_cika_beehive_clear as it's serializer returned null
# [01:22:33 INFO]: Skipping loading recipe productivebees:hives/advanced_byg_ebony_beehive as it's serializer returned null
# [01:22:33 INFO]: Skipping loading recipe productivebees:expansion_boxes/expansion_box_byg_bulbis as it's serializer returned null
# [01:22:33 INFO]: Skipping loading recipe productivebees:hives/advanced_byg_blue_enchanted_beehive_clear as it's serializer returned null
# [01:22:33 INFO]: Skipping loading recipe ars_elemental:jeed/entrhalled as it's serializer returned null
# [01:22:33 INFO]: Skipping loading recipe productivebees:expansion_boxes/expansion_box_regions_unexplored_willow as it's serializer returned null
# [01:22:33 INFO]: Skipping loading recipe productivebees:hives/advanced_regions_unexplored_joshua_beehive as it's serializer returned null
# [01:22:33 INFO]: Skipping loading recipe productivebees:hives/advanced_biomesoplenty_dead_beehive_clear as it's serializer returned null
# [01:22:33 INFO]: Skipping loading recipe productivebees:hives/advanced_byg_fir_beehive as it's serializer returned null
# [01:22:33 INFO]: Skipping loading recipe productivebees:hives/advanced_byg_blue_enchanted_beehive as it's serializer returned null
# [01:22:33 INFO]: Skipping loading recipe productivebees:expansion_boxes/expansion_box_regions_unexplored_blue_bioshroom as it's serializer returned null
# [01:22:33 INFO]: Skipping loading recipe productivebees:expansion_boxes/expansion_box_byg_ebony as it's serializer returned null
# [01:22:33 INFO]: Skipping loading recipe productivebees:hives/advanced_regions_unexplored_pink_bioshroom_beehive as it's serializer returned null
# [01:22:33 INFO]: Skipping loading recipe productivebees:hives/advanced_biomesoplenty_umbran_beehive as it's serializer returned null
# [01:22:33 INFO]: Skipping loading recipe productivebees:expansion_boxes/expansion_box_byg_imparius as it's serializer returned null
# [01:22:33 INFO]: Skipping loading recipe productivebees:hives/advanced_regions_unexplored_green_bioshroom_beehive as it's serializer returned null
# [01:22:33 INFO]: Skipping loading recipe productivebees:expansion_boxes/expansion_box_byg_redwood as it's serializer returned null
# [01:22:33 INFO]: Skipping loading recipe productivebees:hives/advanced_regions_unexplored_green_bioshroom_beehive_clear as it's serializer returned null
# [01:22:33 INFO]: Skipping loading recipe productivebees:hives/advanced_byg_baobab_beehive as it's serializer returned null
# [01:22:33 INFO]: Skipping loading recipe productivebees:hives/advanced_byg_holly_beehive_clear as it's serializer returned null
# [01:22:33 INFO]: Skipping loading recipe productivebees:hives/advanced_regions_unexplored_baobab_beehive_clear as it's serializer returned null
# [01:22:33 INFO]: Skipping loading recipe productivebees:expansion_boxes/expansion_box_regions_unexplored_yellow_bioshroom as it's serializer returned null
# [01:22:33 INFO]: Skipping loading recipe productivebees:expansion_boxes/expansion_box_biomesoplenty_dead as it's serializer returned null
# [01:22:33 INFO]: Skipping loading recipe productivebees:hives/advanced_environmental_wisteria_beehive_clear as it's serializer returned null
# [01:22:33 INFO]: Skipping loading recipe productivebees:expansion_boxes/expansion_box_regions_unexplored_maple as it's serializer returned null
# [01:22:33 INFO]: Skipping loading recipe productivebees:corail/woodcutter/dead_canvas_expansion_box as it's serializer returned null
# [01:22:33 INFO]: Skipping loading recipe productivebees:hives/advanced_byg_lament_beehive_clear as it's serializer returned null
# [01:22:33 INFO]: Skipping loading recipe productivebees:hives/advanced_byg_embur_beehive as it's serializer returned null
# [01:22:33 INFO]: Skipping loading recipe productivebees:hives/advanced_atmospheric_grimwood_beehive_clear as it's serializer returned null
# [01:22:33 INFO]: Skipping loading recipe productivebees:hives/advanced_upgrade_aquatic_river_beehive as it's serializer returned null
# [01:22:33 INFO]: Skipping loading recipe productivebees:hives/advanced_biomesoplenty_jacaranda_beehive_clear as it's serializer returned null
# [01:22:33 INFO]: Skipping loading recipe productivebees:hives/advanced_regions_unexplored_larch_beehive_clear as it's serializer returned null
# [01:22:33 INFO]: Skipping loading recipe twilightforest:jeed/poison as it's serializer returned null
# [01:22:33 INFO]: Skipping loading recipe productivebees:hives/advanced_atmospheric_morado_beehive as it's serializer returned null
# [01:22:33 INFO]: Skipping loading recipe productivebees:corail/woodcutter/aspen_canvas_expansion_box as it's serializer returned null
# [01:22:33 INFO]: Skipping loading recipe productivebees:hives/advanced_byg_cika_beehive as it's serializer returned null
# [01:22:33 INFO]: Skipping loading recipe productivebees:expansion_boxes/expansion_box_byg_pine as it's serializer returned null
# [01:22:33 INFO]: Skipping loading recipe productivebees:hives/advanced_regions_unexplored_cypress_beehive as it's serializer returned null
# [01:22:33 INFO]: Skipping loading recipe productivebees:hives/advanced_quark_blossom_beehive as it's serializer returned null
# [01:22:33 INFO]: Skipping loading recipe productivebees:hives/advanced_regions_unexplored_pine_beehive_clear as it's serializer returned null
# [01:22:33 INFO]: Skipping loading recipe productivebees:expansion_boxes/expansion_box_byg_fir as it's serializer returned null
# [01:22:33 INFO]: Skipping loading recipe productivebees:hives/advanced_regions_unexplored_joshua_beehive_clear as it's serializer returned null
# [01:22:33 INFO]: Skipping loading recipe productivebees:hives/advanced_atmospheric_kousa_beehive as it's serializer returned null
# [01:22:33 INFO]: Skipping loading recipe productivebees:expansion_boxes/expansion_box_regions_unexplored_redwood as it's serializer returned null
# [01:22:33 INFO]: Skipping loading recipe productivebees:expansion_boxes/expansion_box_biomesoplenty_umbran as it's serializer returned null
# [01:22:33 INFO]: Skipping loading recipe productivebees:expansion_boxes/expansion_box_atmospheric_rosewood as it's serializer returned null
# [01:22:33 INFO]: Skipping loading recipe productivebees:corail/woodcutter/rosewood_canvas_hive as it's serializer returned null
# [01:22:33 INFO]: Skipping loading recipe productivebees:expansion_boxes/expansion_box_upgrade_aquatic_driftwood as it's serializer returned null
# [01:22:33 INFO]: Skipping loading recipe productivebees:hives/advanced_regions_unexplored_dead_beehive_clear as it's serializer returned null
# [01:22:33 INFO]: Skipping loading recipe productivebees:corail/woodcutter/comb_canvas_hive as it's serializer returned null
# [01:22:33 INFO]: Skipping loading recipe productivebees:hives/advanced_byg_maple_beehive_clear as it's serializer returned null
# [01:22:33 INFO]: Skipping loading recipe ars_elemental:jeed/watery_grave as it's serializer returned null
# [01:22:33 INFO]: Skipping loading recipe productivebees:hives/advanced_byg_nightshade_beehive_clear as it's serializer returned null
# [01:22:33 INFO]: Skipping loading recipe productivebees:expansion_boxes/expansion_box_byg_willow as it's serializer returned null
# [01:22:33 INFO]: Skipping loading recipe productivebees:corail/woodcutter/jungle_canvas_hive as it's serializer returned null
# [01:22:33 WARN]: Your custom createaddition:rolling/electrum_plate recipe (createaddition:rolling/electrum_plate) specified a duration. Durations have no impact on this type of recipe.
# [01:22:33 INFO]: Skipping loading recipe productivebees:hives/advanced_atmospheric_aspen_beehive_clear as it's serializer returned null
# [01:22:33 INFO]: Skipping loading recipe productivebees:corail/woodcutter/rosewood_canvas_expansion_box as it's serializer returned null
# [01:22:33 INFO]: Skipping loading recipe productivebees:corail/woodcutter/maple_canvas_hive as it's serializer returned null
# [01:22:33 INFO]: Skipping loading recipe productivebees:hives/advanced_byg_willow_beehive_clear as it's serializer returned null
# [01:22:33 INFO]: Skipping loading recipe productivebees:expansion_boxes/expansion_box_atmospheric_grimwood as it's serializer returned null
# [01:22:33 INFO]: Skipping loading recipe productivebees:expansion_boxes/expansion_box_byg_green_enchanted as it's serializer returned null
# [01:22:33 INFO]: Skipping loading recipe productivebees:hives/advanced_regions_unexplored_alpha_oak_beehive as it's serializer returned null
# [01:22:33 INFO]: Skipping loading recipe productivebees:hives/advanced_biomesoplenty_umbran_beehive_clear as it's serializer returned null
# [01:22:33 INFO]: Skipping loading recipe productivebees:hives/advanced_regions_unexplored_blackwood_beehive_clear as it's serializer returned null
# [01:22:33 INFO]: Skipping loading recipe productivebees:corail/woodcutter/jacaranda_canvas_expansion_box as it's serializer returned null
# [01:22:33 INFO]: Skipping loading recipe productivebees:expansion_boxes/expansion_box_regions_unexplored_mauve as it's serializer returned null
# [01:22:33 ERROR]: Parsing error loading recipe railways:sequenced_assembly/track_blue_skies_cherry: com.google.gson.JsonSyntaxException: Unknown item 'blue_skies:cherry_slab'
# [01:22:33 ERROR]: Parsing error loading recipe create:cutting/compat/blue_skies/cherry_wood: com.google.gson.JsonSyntaxException: Unknown item 'blue_skies:cherry_wood'
# [01:22:33 INFO]: Skipping loading recipe productivebees:hives/advanced_byg_skyris_beehive as it's serializer returned null
# [01:22:33 INFO]: Skipping loading recipe productivebees:corail/woodcutter/acacia_canvas_expansion_box as it's serializer returned null
# [01:22:33 INFO]: Skipping loading recipe productivebees:expansion_boxes/expansion_box_byg_witch_hazel as it's serializer returned null
# [01:22:33 INFO]: Skipping loading recipe productivebees:hives/advanced_regions_unexplored_kapok_beehive as it's serializer returned null
# [01:22:33 INFO]: Skipping loading recipe productivebees:corail/woodcutter/grimwood_canvas_expansion_box as it's serializer returned null
# [01:22:33 INFO]: Skipping loading recipe productivebees:hives/advanced_endergetic_poise_beehive as it's serializer returned null
# [01:22:33 INFO]: Skipping loading recipe productivebees:hives/advanced_byg_imparius_beehive_clear as it's serializer returned null
# [01:22:33 INFO]: Skipping loading recipe productivebees:hives/advanced_byg_imparius_beehive as it's serializer returned null
# [01:22:33 INFO]: Skipping loading recipe productivebees:hives/advanced_biomesoplenty_willow_beehive_clear as it's serializer returned null
# [01:22:33 INFO]: Skipping loading recipe toolbelt:pouch_upgrade_6_via_sewing as it's serializer returned null
# [01:22:33 INFO]: Skipping loading recipe productivebees:hives/advanced_byg_embur_beehive_clear as it's serializer returned null
# [01:22:33 INFO]: Skipping loading recipe productivebees:corail/woodcutter/dark_oak_canvas_expansion_box as it's serializer returned null
# [01:22:33 WARN]: Your custom createaddition:rolling/iron_plate recipe (createaddition:rolling/iron_plate) specified a duration. Durations have no impact on this type of recipe.
# [01:22:33 INFO]: Skipping loading recipe productivebees:expansion_boxes/expansion_box_regions_unexplored_baobab as it's serializer returned null
# [01:22:33 INFO]: Skipping loading recipe productivebees:corail/woodcutter/mahogany_canvas_hive as it's serializer returned null
# [01:22:33 INFO]: Skipping loading recipe ars_elemental:jeed/mana_shield as it's serializer returned null
# [01:22:33 INFO]: Skipping loading recipe productivebees:hives/advanced_byg_palm_beehive_clear as it's serializer returned null
# [01:22:33 INFO]: Skipping loading recipe productivebees:corail/woodcutter/yucca_canvas_expansion_box as it's serializer returned null
# [01:22:33 INFO]: Skipping loading recipe productivebees:hives/advanced_regions_unexplored_baobab_beehive as it's serializer returned null
# [01:22:33 INFO]: Skipping loading recipe toolbelt:pouch_via_sewing as it's serializer returned null
# [01:22:33 INFO]: Skipping loading recipe productivebees:hives/advanced_regions_unexplored_eucalyptus_beehive_clear as it's serializer returned null
# [01:22:33 INFO]: Skipping loading recipe productivebees:corail/woodcutter/kousa_canvas_expansion_box as it's serializer returned null
# [01:22:33 INFO]: Skipping loading recipe productivebees:hives/advanced_biomesoplenty_mahogany_beehive as it's serializer returned null
# [01:22:33 INFO]: Skipping loading recipe productivebees:hives/advanced_biomesoplenty_redwood_beehive as it's serializer returned null
# [01:22:33 INFO]: Skipping loading recipe productivebees:corail/woodcutter/driftwood_canvas_hive as it's serializer returned null
# ...
# [01:22:34 INFO]: Registered 7 gateways.
# [01:22:34 INFO]: 19 Broom modifiers can be applied!
# [01:22:35 INFO]: Starting minecraft server version 1.20.1
# [01:22:35 INFO]: Loading properties
# [01:22:35 INFO]: Default game type: SURVIVAL
# [01:22:35 INFO]: Generating keypair
# [01:22:35 INFO]: Starting Minecraft server on *:25565
# [01:22:35 INFO]: Using epoll channel type
# [01:22:35 WARN]: **** SERVER IS RUNNING IN OFFLINE/INSECURE MODE!
# [01:22:35 WARN]: The server will make no attempt to authenticate usernames. Beware.
# [01:22:35 WARN]: While this makes the game possible to play without internet access, it also opens up the ability for hackers to connect with any username they choose.
# [01:22:35 WARN]: To change this, set "online-mode" to "true" in the server.properties file.
# [01:22:35 INFO]: This server is running Mohist version 1.20.1-580 (MC: 1.20.1) (Implementing API version 1.20.1-R0.1-SNAPSHOT, Forge version 47.2.20, NeoForge version 47.1.79)
# [01:22:37 INFO]: Finalizing energy block registration
# [01:22:37 INFO]: Finalizing fluid block registration
# [01:22:38 INFO]: Debug logging is enabled
# [01:22:38 INFO]: Server Ping Player Sample Count: 20
# [01:22:38 INFO]: Using 4 threads for Netty based IO
# [01:22:38 INFO]: Hello Plugins!
# [01:22:40 INFO]: [LuckPerms] Loading LuckPerms v5.4.119
# [01:22:40 INFO]: [SkinsRestorer] Loading SkinsRestorer v15.0.7
# [01:22:40 INFO]: [Vault] Loading Vault v1.7.3-b131
# [01:22:40 INFO]: [Essentials] Loading Essentials v2.21.0-dev+68-993d7ed
# [01:22:41 INFO]: [DiscordSRV] Loading DiscordSRV v1.27.0
# [01:22:41 INFO]: [LuckPerms] Enabling LuckPerms v5.4.119
# [01:22:41 INFO]: Patching IForgeItemStack#getEnchantmentLevel
# [01:22:41 INFO]: Patching IForgeItemStack#getEnchantmentLevel
# [01:22:42 INFO]:         __
# [01:22:42 INFO]:   |    |__)   LuckPerms v5.4.119
# [01:22:42 INFO]:   |___ |      Running on Bukkit - Mohist
# [01:22:42 INFO]:
# [01:22:42 INFO]: [LuckPerms] Loading configuration...
# [01:22:42 INFO]: [LuckPerms] Loading storage provider... [YAML]
# [01:22:43 INFO]: [LuckPerms] Loading internal permission managers...
# [01:22:43 INFO]: [LuckPerms] Performing initial data load...
# [01:22:43 INFO]: [LuckPerms] Successfully enabled. (took 2826ms)
# [01:22:43 INFO]: [SkinsRestorer] Enabling SkinsRestorer v15.0.7
# [01:22:45 INFO]: [SkinsRestorer] Running on Minecraft 1.20.1.
# [01:22:46 INFO]: [Vault] Enabling Vault v1.7.3-b131
# [01:22:46 WARN]: [Vault] Loaded class com.earth2me.essentials.api.Economy from Essentials v2.21.0-dev+68-993d7ed which is not a depend or softdepend of this plugin.
# [01:22:46 INFO]: [Vault] [Economy] Essentials Economy found: Waiting
# [01:22:47 INFO]: [Vault] [Permission] SuperPermissions loaded as backup permission system.
# [01:22:48 INFO]: [Vault] Enabled Version 1.7.3-b131
# [01:22:48 INFO]: [LuckPerms] Registered Vault permission & chat hook.
# [01:22:48 INFO]: Loading server config for mutantmonsters
# [01:22:48 INFO]: Loading JourneyMap Forge Configs
# [01:22:48 INFO]: Loaded Create Ore Excavation config file createoreexcavation-server.toml
# [01:22:48 INFO]: Starting background profiler...
# [01:22:49 INFO]: Loading server configs...
# [01:22:49 INFO]: Initialized TerraBlender biomes for level stem aether:the_aether
# [01:22:49 INFO]: Initialized TerraBlender biomes for level stem minecraft:overworld
# [01:22:49 INFO]: Initialized TerraBlender biomes for level stem minecraft:the_nether
# [01:22:49 INFO]: Preparing level "world"
# [01:22:50 WARN]: @Redirect conflict. Skipping securitycraft.mixins.json:camera.ChunkMapMixin->@Redirect::securitycraft$getCameraSectionPos(Lnet/minecraft/server/level/ServerPlayer;)Lnet/minecraft/core/SectionPos; with priority 1100, already redirected by railways-common.mixins.json:conductor_possession.ChunkMapMixin->@Redirect::securitycraft$getCameraSectionPos(Lnet/minecraft/server/level/ServerPlayer;)Lnet/minecraft/core/SectionPos; with priority 1200
# [01:22:50 INFO]: Preparing start region for dimension minecraft:overworld
# [01:22:51 INFO]: Preparing spawn area: 0%
# [01:22:51 INFO]: Preparing spawn area: 0%
# [01:22:51 INFO]: Preparing spawn area: 0%
# [01:22:52 INFO]: Preparing spawn area: 7%
# [01:22:52 INFO]: Preparing spawn area: 14%
# [01:22:53 INFO]: Preparing spawn area: 41%
# [01:22:53 INFO]: Time elapsed: 2984 ms
# [01:22:53 INFO]: Preparing start region for dimension aether:the_aether
# [01:22:54 INFO]: Preparing spawn area: 0%
# [01:22:54 INFO]: Preparing spawn area: 0%
# [01:22:54 INFO]: Preparing spawn area: 45%
# [01:22:55 INFO]: Preparing spawn area: 94%
# [01:22:55 INFO]: Time elapsed: 1556 ms
# [01:22:55 INFO]: Preparing start region for dimension the_bumblezone:the_bumblezone
# [01:22:55 INFO]: Preparing spawn area: 0%
# [01:22:55 INFO]: Preparing spawn area: 9%
# [01:22:56 INFO]: Preparing spawn area: 25%
# [01:22:56 INFO]: Preparing spawn area: 51%
# [01:22:57 INFO]: Time elapsed: 1982 ms
# [01:22:57 INFO]: Preparing start region for dimension ad_astra:venus
# [01:22:57 INFO]: Preparing spawn area: 0%
# [01:22:57 INFO]: Preparing spawn area: 25%
# [01:22:58 INFO]: Preparing spawn area: 68%
# [01:22:58 INFO]: Time elapsed: 1391 ms
# [01:22:58 INFO]: Preparing start region for dimension ad_astra:venus_orbit
# [01:22:58 INFO]: Preparing spawn area: 0%
# [01:22:59 INFO]: Preparing spawn area: 25%
# [01:22:59 INFO]: Preparing spawn area: 86%
# [01:22:59 INFO]: Time elapsed: 1080 ms
# [01:22:59 INFO]: Preparing start region for dimension deeperdarker:otherside
# [01:22:59 INFO]: Preparing spawn area: 0%
# [01:23:00 INFO]: Preparing spawn area: 27%
# [01:23:00 INFO]: Preparing spawn area: 98%
# [01:23:00 INFO]: Time elapsed: 1005 ms
# [01:23:00 INFO]: Preparing start region for dimension blue_skies:everbright
# [01:23:00 INFO]: Preparing spawn area: 0%
# [01:23:01 INFO]: Preparing spawn area: 15%
# [01:23:01 INFO]: Preparing spawn area: 44%
# [01:23:02 INFO]: Time elapsed: 1440 ms
# [01:23:02 INFO]: Preparing start region for dimension ad_astra:glacio
# [01:23:02 INFO]: Preparing spawn area: 0%
# [01:23:02 INFO]: Preparing spawn area: 30%
# [01:23:03 INFO]: Time elapsed: 949 ms
# [01:23:03 INFO]: Preparing start region for dimension ad_astra:mars
# [01:23:03 INFO]: Preparing spawn area: 0%
# [01:23:03 INFO]: Preparing spawn area: 43%
# [01:23:04 INFO]: Time elapsed: 792 ms
# [01:23:04 INFO]: Preparing start region for dimension ad_astra:mercury
# [01:23:04 INFO]: Preparing spawn area: 0%
# [01:23:04 INFO]: Preparing spawn area: 30%
# [01:23:04 INFO]: Time elapsed: 870 ms
# [01:23:04 INFO]: Preparing start region for dimension twilightforest:twilight_forest
# [01:23:04 INFO]: Preparing spawn area: 0%
# [01:23:05 INFO]: Preparing spawn area: 20%
# [01:23:06 INFO]: Time elapsed: 1066 ms
# [01:23:06 INFO]: Preparing start region for dimension ad_astra:glacio_orbit
# [01:23:06 INFO]: Preparing spawn area: 0%
# [01:23:06 INFO]: Preparing spawn area: 57%
# [01:23:06 INFO]: Time elapsed: 676 ms
# [01:23:06 INFO]: Preparing start region for dimension blue_skies:everdawn
# [01:23:06 INFO]: Preparing spawn area: 0%
# [01:23:07 INFO]: Preparing spawn area: 11%
# [01:23:07 INFO]: Preparing spawn area: 70%
# [01:23:07 INFO]: Time elapsed: 1134 ms
# [01:23:07 INFO]: Preparing start region for dimension dimdungeons:build_dimension
# [01:23:07 INFO]: Preparing spawn area: 0%
# [01:23:08 INFO]: Preparing spawn area: 60%
# [01:23:08 INFO]: Time elapsed: 665 ms
# [01:23:08 INFO]: Preparing start region for dimension ad_astra:mercury_orbit
# [01:23:08 INFO]: Preparing spawn area: 0%
# [01:23:09 INFO]: Preparing spawn area: 58%
# [01:23:09 INFO]: Time elapsed: 648 ms
# [01:23:09 INFO]: Preparing start region for dimension dimdungeons:dungeon_dimension
# [01:23:09 INFO]: Preparing spawn area: 0%
# [01:23:09 INFO]: Preparing spawn area: 55%
# [01:23:09 INFO]: Time elapsed: 700 ms
# [01:23:09 INFO]: Preparing start region for dimension ad_astra:moon_orbit
# [01:23:09 INFO]: Preparing spawn area: 0%
# [01:23:10 INFO]: Preparing spawn area: 47%
# [01:23:10 INFO]: Time elapsed: 715 ms
# [01:23:10 INFO]: Preparing start region for dimension ad_astra:mars_orbit
# [01:23:10 INFO]: Preparing spawn area: 0%
# [01:23:11 INFO]: Preparing spawn area: 41%
# [01:23:11 INFO]: Time elapsed: 830 ms
# [01:23:11 INFO]: Preparing start region for dimension ad_astra:moon
# [01:23:11 INFO]: Preparing spawn area: 0%
# [01:23:11 INFO]: Preparing spawn area: 36%
# [01:23:12 INFO]: Time elapsed: 890 ms
# [01:23:12 INFO]: Preparing start region for dimension ad_astra:earth_orbit
# [01:23:12 INFO]: Preparing spawn area: 0%
# [01:23:12 INFO]: Preparing spawn area: 62%
# [01:23:12 INFO]: Time elapsed: 668 ms
# [01:23:13 INFO]: [Essentials] Enabling Essentials v2.21.0-dev+68-993d7ed
# [01:23:13 ERROR]: You are running a server that does not properly support Bukkit plugins. Bukkit plugins should not be used with Forge/Fabric mods! For Forge: Consider using ForgeEssentials, or SpongeForge + Nucleus.
# [01:23:13 INFO]: Status determining class: brand:Mohist
# [01:23:13 INFO]: Attempting to convert old kits in config.yml to new kits.yml
# [01:23:13 INFO]: No kits found to migrate.
# [01:23:14 INFO]: Loaded 39095 items from items.json.
# [01:23:14 INFO]: Using locale es
# [01:23:14 INFO]: ServerListPingEvent: Spigot iterator API
# [01:23:14 INFO]: Starting Metrics. Opt-out using the global bStats config.
# [01:23:14 INFO]: [Vault] [Economy] Essentials Economy hooked.
# [01:23:14 INFO]: Using Vault based permissions (LuckPerms)
# [01:23:14 INFO]: [DiscordSRV] Enabling DiscordSRV v1.27.0
# [01:23:14 INFO]: [Mohist] Enabling Mohist v1.20.1
# [01:23:14 INFO]: Server permissions file permissions.yml is empty, ignoring it
# [01:23:15 INFO]: Done (26.501s)! For help, type "help"
# [01:23:15 INFO]: Successfully initialized permission handler forge:default_handler
# [01:23:15 INFO]: Forwarding forge permission[forge:default_handler] to bukkit[mohist:permission]
# [01:23:15 INFO]: Thanks for choosing Terralith!
# [01:23:15 INFO]: Loading infobook /data/cyclopscore/info/test.xml
# [01:23:15 INFO]: Loading infobook /data/evilcraft/info/book.xml
# [01:23:15 WARN]: Invalid appendix info_book.evilcraft.second_age.tools.broom from mod evilcraft in an infobook: The broom modifier evilcraft:witherer has no valid items
# [01:23:15 WARN]: Invalid appendix info_book.evilcraft.second_age.tools.broom from mod evilcraft in an infobook: The broom modifier evilcraft:hungerer has no valid items
# [01:23:15 WARN]: Invalid appendix info_book.evilcraft.second_age.tools.broom from mod evilcraft in an infobook: The broom modifier evilcraft:kamikaze has no valid items
# [01:23:15 WARN]: Invalid appendix info_book.evilcraft.second_age.tools.broom from mod evilcraft in an infobook: The broom modifier evilcraft:withershield has no valid items
# [01:23:15 INFO]: Skipped section info_book.evilcraftcompat.mod_integrations.baubles due to unsatisfied mod condition.
# [01:23:15 INFO]: Skipped section info_book.evilcraftcompat.mod_integrations.blood_magic due to unsatisfied mod condition.
# [01:23:15 INFO]: Skipped section info_book.evilcraftcompat.mod_integrations.ee3 due to unsatisfied mod condition.
# [01:23:15 INFO]: Skipped section info_book.evilcraftcompat.mod_integrations.enderio due to unsatisfied mod condition.
# [01:23:15 INFO]: Skipped section info_book.evilcraftcompat.mod_integrations.forestry due to unsatisfied mod condition.
# [01:23:15 INFO]: Skipped section info_book.evilcraftcompat.mod_integrations.ic2 due to unsatisfied mod condition.
# [01:23:15 INFO]: Skipped section info_book.evilcraftcompat.mod_integrations.immersiveengineering due to unsatisfied mod condition.
# [01:23:15 INFO]: Skipped section info_book.evilcraftcompat.mod_integrations.thaumcraft due to unsatisfied mod condition.
# [01:23:15 INFO]: Skipped section info_book.evilcraftcompat.mod_integrations.thermal_expansion due to unsatisfied mod condition.
# [01:23:15 INFO]: Skipped section info_book.evilcraftcompat.mod_integrations.tinkers_construct due to unsatisfied mod condition.
# [01:23:15 INFO]: Skipped section info_book.evilcraftcompat.mod_integrations.waila due to unsatisfied mod condition.
# [01:23:15 INFO]: Loaded config for: smoothchunk.json
# [01:23:15 INFO]: [DiscordSRV] DiscordSRV is up-to-date. (6405e850eea61a4b9bf4f0d0cbb80fe20b3cfb90)
# [01:23:15 INFO]: Finished discovering Ores 78 76
# [01:23:15 INFO]: Finished discovering saplings 37
# [01:23:15 INFO]: Finished discovering plantables 19
# [01:23:15 INFO]: Finished discovering food 355 397
# [01:23:15 INFO]: Finished discovering fuel 883
# [01:23:15 INFO]: Finished discovering flowers 134
# [01:23:15 INFO]: Finished discovering items 14597
# [01:23:15 INFO]: Finished discovering lucky oreBlocks 6
# [01:23:15 INFO]: Finished discovering recruitment costs
# [01:23:15 INFO]: Finished discovering diseases
# [01:23:15 INFO]: Finished discovering compostables 616
# [01:23:16 INFO]: Sending reload packet to clients
# [01:23:16 WARN]: Dedicated server took 114.38 seconds to load
# [01:23:16 INFO]: Essentials found a compatible payment resolution method: Vault Compatibility Layer (v1.7.3-b131)!
# [01:23:16 INFO]: [Vault] Checking for Updates ...
# [01:23:16 INFO]: Obteniendo información de versión...
# [01:23:16 INFO]: [SkinsRestorer] ----------------------------------------------
# [01:23:16 INFO]: [SkinsRestorer]     +==================+
# [01:23:16 INFO]: [SkinsRestorer]     |   SkinsRestorer  |
# [01:23:16 INFO]: [SkinsRestorer]     |------------------|
# [01:23:16 INFO]: [SkinsRestorer]     |  Standalone Mode |
# [01:23:16 INFO]: [SkinsRestorer]     +==================+
# [01:23:16 INFO]: [SkinsRestorer] ----------------------------------------------
# [01:23:16 INFO]: [SkinsRestorer]     Version: 15.0.7
# [01:23:16 INFO]: [SkinsRestorer]     Commit: 301d078
# [01:23:16 INFO]: [SkinsRestorer]     This is the latest version!
# [01:23:16 INFO]: [SkinsRestorer] ----------------------------------------------
# [01:23:16 INFO]: [Vault] No new version available
# [01:23:17 INFO]: [DiscordSRV] [JDA] Login Successful!
# [01:23:17 INFO]: [DiscordSRV] [JDA] Connected to WebSocket
# [01:23:18 INFO]: [DiscordSRV] [JDA] Finished Loading!
# [01:23:18 INFO]: [DiscordSRV] Found server G:The Entonces(1009997158486900786)
# [01:23:18 INFO]: [DiscordSRV] - TC:📍▸entrada(1009997159178969240)
# [01:23:18 INFO]: [DiscordSRV] - TC:📰▸anuncios(1089113769323528192)
# [01:23:18 INFO]: [DiscordSRV] - TC:🌈▸colores(1011674594811326514)
# [01:23:18 INFO]: [DiscordSRV] - TC:📰▸anuncios(1195202869217988628)
# [01:23:18 INFO]: [DiscordSRV] - TC:🌎▸general(1009998915535388742)
# [01:23:18 INFO]: [DiscordSRV] - TC:☁▸valorant-egoleh(1111014840316723241)
# [01:23:18 INFO]: [DiscordSRV] - TC:💌▸publico(1177787121633861632)
# [01:23:18 INFO]: [DiscordSRV] - TC:🎁▸cumpleaños(1204233886117265469)
# [01:23:18 INFO]: [DiscordSRV] - TC:🧩▸server(1213188610921205770)
# [01:23:18 INFO]: [DiscordSRV] - TC:♻▸chat(1213000229557899295)
# [01:23:18 INFO]: [DiscordSRV] - TC:🗺▸consola(1213000039555670086)
# [01:23:18 INFO]: [DiscordSRV] - TC:musica(1090431621557133382)
# [01:23:18 INFO]: [DiscordSRV] - TC:🔇retrasados-sin-mic(1197344910915944559)
# [01:23:18 INFO]: [DiscordSRV] - TC:⛏▸minecraft(1089113848222584842)
# [01:23:18 INFO]: [DiscordSRV] - TC:🔫▸left-4-dead(1179568100237115393)
# [01:23:18 INFO]: [DiscordSRV] - TC:🔔▸streams(1121234662858162236)
# [01:23:18 INFO]: [DiscordSRV] - TC:💠▸sv-minecraft(1182222075235156040)
# [01:23:18 INFO]: [DiscordSRV] - TC:miras-cb(1064668844838355034)
# [01:23:18 INFO]: [DiscordSRV] - TC:configurar(1012065772094378167)
# [01:23:18 INFO]: [DiscordSRV] - TC:log(1158169487166689393)
# [01:23:18 INFO]: [DiscordSRV] - TC:🍒▸spam(1045374065076093009)
# [01:23:18 INFO]: [DiscordSRV] - TC:💌▸txt(1141891008246845500)
# [01:23:18 INFO]: [DiscordSRV] - TC:🎁▸cumpleaños(1012478668259479613)
# [01:23:18 INFO]: [DiscordSRV] - TC:🔢▸contador(1158167925816033320)
# [01:23:18 INFO]: [DiscordSRV] - TC:🔢▸contador-log(1158175182444298302)
# [01:23:18 INFO]: [DiscordSRV] Console forwarding assigned to channel TC:🗺▸consola(1213000039555670086)
# [01:23:19 INFO]: [DiscordSRV] Cleared all pre-existing slash commands in 1/1 guilds (0 cancelled)
# [01:23:19 INFO]: [DiscordSRV] Enabling Essentials hook
# [01:23:19 INFO]: [DiscordSRV] Enabling LuckPerms hook
# >
# >=>
# >[01:26:53 INFO]: Stopping server
# [01:26:53 INFO]: [Mohist] Disabling Mohist v1.20.1
# [01:26:53 INFO]: [DiscordSRV] Disabling DiscordSRV v1.27.0
